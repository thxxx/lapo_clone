# %%
import config
import data_loader
import doy
import paths
import torch
import utils
from doy import loop

env_name = "bigfish"

sweep_name=doy.random_proquint(2)
print(sweep_name)
ind=0
exp_name=f"{ind}_{sweep_name}"

cfg = config.get()
doy.print("[bold green]Running LAPO stage 1 (IDM/FDM training) with config:")
config.print_cfg(cfg)
# Out:
# vovog-sudig
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 16
#      13 ind=0
#      14 exp_name=f"{ind}_{sweep_name}"
# ---> 16 cfg = config.get()
#      17 doy.print("[bold green]Running LAPO stage 1 (IDM/FDM training) with config:")
#      18 config.print_cfg(cfg)
#
# File /workspace/lapo_clone/lapo/config.py:123, in get(base_cfg, use_cli_args, override_args, reload_keys)
#     120 _apply_runtime_vals(cfg)  # type: ignore
#     122 cfg_schema: Config = OmegaConf.structured(Config)
# --> 123 return OmegaConf.merge(cfg_schema, cfg)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/omegaconf.py:273, in OmegaConf.merge(*configs)
#     270 assert isinstance(target, (DictConfig, ListConfig))
#     272 with flag_override(target, "readonly", False):
# --> 273     target.merge_with(*configs[1:])
#     274     turned_readonly = target._get_flag("readonly") is True
#     276 if turned_readonly:
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/basecontainer.py:492, in BaseContainer.merge_with(self, *others)
#     490     self._merge_with(*others)
#     491 except Exception as e:
# --> 492     self._format_and_raise(key=None, value=None, cause=e)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/_utils.py:819, in format_and_raise(node, key, value, msg, cause, type_override)
#     817         ex = type_override(str(cause))
#     818         ex.__dict__ = copy.deepcopy(cause.__dict__)
# --> 819     _raise(ex, cause)
#     821 object_type: Optional[Type[Any]]
#     822 object_type_str: Optional[str] = None
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/basecontainer.py:490, in BaseContainer.merge_with(self, *others)
#     483 def merge_with(
#     484     self,
#     485     *others: Union[
#     486         "BaseContainer", Dict[str, Any], List[Any], Tuple[Any, ...], Any
#     487     ],
#     488 ) -> None:
#     489     try:
# --> 490         self._merge_with(*others)
#     491     except Exception as e:
#     492         self._format_and_raise(key=None, value=None, cause=e)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/basecontainer.py:514, in BaseContainer._merge_with(self, *others)
#     511 other = _ensure_container(other, flags=my_flags)
#     513 if isinstance(self, DictConfig) and isinstance(other, DictConfig):
# --> 514     BaseContainer._map_merge(self, other)
#     515 elif isinstance(self, ListConfig) and isinstance(other, ListConfig):
#     516     BaseContainer._list_merge(self, other)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/basecontainer.py:423, in BaseContainer._map_merge(dest, src)
#     420                         dest_node._set_value(src_value)
#     422             except (ValidationError, ReadonlyConfigError) as e:
# --> 423                 dest._format_and_raise(key=key, value=src_value, cause=e)
#     424 else:
#     425     from omegaconf import open_dict
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/basecontainer.py:420, in BaseContainer._map_merge(dest, src)
#     418     else:
#     419         if not src_node_missing:
# --> 420             dest_node._set_value(src_value)
#     422 except (ValidationError, ReadonlyConfigError) as e:
#     423     dest._format_and_raise(key=key, value=src_value, cause=e)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/nodes.py:46, in ValueNode._set_value(self, value, flags)
#      44     self._val = value
#      45 else:
# ---> 46     self._val = self.validate_and_convert(value)
#
# File /usr/local/lib/python3.10/dist-packages/omegaconf/nodes.py:66, in ValueNode.validate_and_convert(self, value)
#      64         return None
#      65     ref_type_str = type_str(self._metadata.ref_type)
# ---> 66     raise ValidationError(
#      67         f"Incompatible value '{value}' for field of type '{ref_type_str}'"
#      68     )
#      70 # Subclasses can assume that `value` is not None in
#      71 # `_validate_and_convert_impl()` and in `_strict_validate_type()`.
#      72 if self._get_flag("convert") is False:
#
# ValidationError: Incompatible value 'None' for field of type 'str'
#     full_key: exp_name
#     object_type=Config
