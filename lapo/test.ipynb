# %%
import config
import data_loader
import doy
import paths
import torch
import utils
from doy import loop

env_name = "bigfish"

sweep_name=doy.random_proquint(2)
print(sweep_name)
ind=0
exp_name=f"{ind}_{sweep_name}"

cfg = config.get(use_cli_args=False)
doy.print("[bold green]Running LAPO stage 1 (IDM/FDM training) with config:")
config.print_cfg(cfg)
# Out:
# biris-guzij
# Running LAPO stage 1 (IDM/FDM training) with config:
# env_name: bigfish
# exp_name: 0_testfor~
# stage_exp_name: null
# model:
#   wm_scale: 24
#   idm_impala_scale: 4
#   policy_impala_scale: 4
#   vq:
#     enabled: true
#     num_codebooks: 2
#     num_discrete_latents: 4
#     emb_dim: 16
#     num_embs: 64
#     commitment_cost: 0.05
#     decay: 0.999
#   la_dim: 128
#   ta_dim: 15
# stage1:
#   lr: 0.0003
#   bs: 128
#   steps: 50000
# stage2:
#   lr: 0.0002
#   bs: 128
#   steps: 60000
# stage3:
#   steps: 4000000
#   num_envs: 64
#   grad_accum_f: 1
#   num_steps: 64
#   num_minibatches: 8
#   update_epochs: 3
#   ent_coef: 0.0025
#   lr: 0.01
#   anneal_lr: true
#   norm_adv: true
#   clip_coef: 0.2
#   clip_vloss: true
#   vf_coef: 0.5
#   max_grad_norm: 0.5
#   target_kl: null
#   gamma: 0.999
#   gae_lambda: 0.95
#   batch_size: 4096
#   minibatch_size: 512
